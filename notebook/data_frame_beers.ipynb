# %%
#import necessary modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# convert the list of beers links to a DataFrame
df = pd.read_excel('../beers_spain.xlsx')

# %%
#print the DataFrame
df
# Out:
#                                            Product Link  \
# 0     https://soysuper.com/p/cervezas-rosa-blanca-pa...
# 1     https://soysuper.com/p/cervezas-mini-estrella-...
# 2     https://soysuper.com/p/cervezas-cruzcampo-pack...
# 3     https://soysuper.com/p/cerveza-estrella-galici...
# 4     https://soysuper.com/p/heineken-cervezas-heine...
# ...                                                 ...
# 1218  https://soysuper.com/search?q=cervezas&categor...
# 1219  https://soysuper.com/search?q=cervezas&categor...
# 1220  https://soysuper.com/search?q=cervezas&categor...
# 1221  https://soysuper.com/search?q=cervezas&categor...
# 1222  https://soysuper.com/search?q=cervezas&categor...
#
#                                             Name Main Price  \
# 0     Rosa Blanca Cervezas\nRosa blanca Cervezas     4,37 €
# 1                Estrella Galicia\nCervezas mini    11,49 €
# 2                  Cruzcampo\nCruzcampo Cervezas     8,04 €
# 3            Estrella Galicia\nCervezas Especial    10,63 €
# 4                    Heineken\nHeineken Cervezas     9,74 €
# ...                                          ...        ...
# 1218                                         NaN        NaN
# 1219                                         NaN        NaN
# 1220                                         NaN        NaN
# 1221                                         NaN        NaN
# 1222                                         NaN        NaN
#
#                          Lot Size  \
# 0           / Pack 6 uds. x 25 cl
# 1               / Pack 20 x 20 cl
# 2           / Pack 12 uds x 33 cl
# 3          / Pack 20 uds. x 20 cl
# 4     / Pack de 12 latas de 33 cl
# ...                           ...
# 1218                          NaN
# 1219                          NaN
# 1220                          NaN
# 1221                          NaN
# 1222                          NaN
#
#                                 Supermarkets and Prices  \
# 0                                       Alcampo: 4,37 €
# 1                                       Eroski: 11,49 €
# 2     Mercadona: 5,76 €; Alcampo: 7,53 €; El Corte I...
# 3                   Alcampo: 9,86 €; Carrefour: 11,40 €
# 4     Mercadona: 8,33 €; Alcampo: 8,73 €; Condis: 9,...
# ...                                                 ...
# 1218                                                NaN
# 1219                                                NaN
# 1220                                                NaN
# 1221                                                NaN
# 1222                                                NaN
#
#                                             Description  \
# 0                                                   NaN
# 1                                                   NaN
# 2     Descripción del producto - Cerveza estilo Pils...
# 3                                                   NaN
# 4     Descripción del producto - Es una cerveza seca...
# ...                                                 ...
# 1218                                                NaN
# 1219                                                NaN
# 1220                                                NaN
# 1221                                                NaN
# 1222                                                NaN
#
#                                                   Image
# 0     https://a2.soysuper.com/175f8aab7364c96c12f88f...
# 1     https://a1.soysuper.com/ad3d00baffa73167534a7f...
# 2     https://a2.soysuper.com/bf10649181c8cfa2b925a5...
# 3     https://a1.soysuper.com/2614b35dc24707c6693ef9...
# 4     https://a1.soysuper.com/e4fce10af7cf9a2fbc09af...
# ...                                                 ...
# 1218                                                NaN
# 1219                                                NaN
# 1220                                                NaN
# 1221                                                NaN
# 1222                                                NaN
#
# [1223 rows x 7 columns]

# %%
# remove rows with NaN values in specific columns
df = df.dropna(subset=['Name', 'Main Price', 'lot Size', 'Supermarkets and Prices'])
df = df.reset_index(drop=True)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2416\4177849110.py in ?()
#       1 # remove rows with NaN values in specific columns
# ----> 2 df = df.dropna(subset=['Name', 'Main Price', 'lot Size', 'Supermarkets and Prices'])
#       3 df = df.reset_index(drop=True)
#       4 df
#
# c:\Users\PC\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py in ?(self, axis, how, thresh, subset, inplace, ignore_index)
#    6666             ax = self._get_axis(agg_axis)
#    6667             indices = ax.get_indexer_for(subset)
#    6668             check = indices == -1
#    6669             if check.any():
# -> 6670                 raise KeyError(np.array(subset)[check].tolist())
#    6671             agg_obj = self.take(indices, axis=agg_axis)
#    6672
#    6673         if thresh is not lib.no_default:
#
# KeyError: ['lot Size']

# %%
#edit the 'lot Size' column to remove the '/' character
df['lot Size'] = df['lot Size'].str.replace('/', '',)
df
# Out:
#                                            Product Link  \
# 0     https://soysuper.com/p/cervezas-rosa-blanca-pa...
# 1     https://soysuper.com/p/cervezas-cruzcampo-pack...
# 2     https://soysuper.com/p/cervezas-mini-estrella-...
# 3     https://soysuper.com/p/cerveza-estrella-galici...
# 4     https://soysuper.com/p/heineken-cervezas-heine...
# ...                                                 ...
# 1543  https://soysuper.com/p/sidra-manzana-la-casera...
# 1544  https://soysuper.com/p/bebida-de-malta-lata-33...
# 1545  https://soysuper.com/p/bebida-de-malta-pack-6-...
# 1546  https://soysuper.com/p/sidra-tropical-kopparbe...
# 1547  https://soysuper.com/p/cider-de-manzana-verde-...
#
#                                                    Name Main Price  \
# 0            Rosa Blanca Cervezas\nRosa blanca Cervezas     4,29 €
# 1                         Cruzcampo\nCruzcampo Cervezas     8,04 €
# 2                       Estrella Galicia\nCervezas mini    11,49 €
# 3                   Estrella Galicia\nCervezas Especial    10,63 €
# 4                           Heineken\nHeineken Cervezas     9,61 €
# ...                                                 ...        ...
# 1543            La Casera\nAperitivo de sidra La Casera     1,47 €
# 1544                                Polar\nMaltín Polar     1,62 €
# 1545                            MALTIN\nBebida de malta     6,71 €
# 1546                         Kopparberg\nSidra tropical     2,59 €
# 1547  LADRÓN MANZANAS\nCider de manzana verde ladrón...     1,30 €
#
#                         lot Size  \
# 0            Pack 6 uds. x 25 cl
# 1            Pack 12 uds x 33 cl
# 2                Pack 20 x 20 cl
# 3           Pack 20 uds. x 20 cl
# 4      Pack de 12 latas de 33 cl
# ...                          ...
# 1543                  Lata 33 cl
# 1544                  Lata 33 cl
# 1545      Pack 6 botellas 250 ml
# 1546                  Lata 50 cl
# 1547              Botellín 25 cl
#
#                                 Supermarkets and Prices  \
# 0                                       Alcampo: 4,29 €
# 1     Mercadona: 5,88 €; Alcampo: 7,42 €; Hipercor: ...
# 2                                       Eroski: 11,49 €
# 3                   Alcampo: 9,86 €; Carrefour: 11,40 €
# 4     Mercadona: 8,33 €; Condis: 8,39 €; Alcampo: 8,...
# ...                                                 ...
# 1543                                  Carrefour: 1,47 €
# 1544  Carrefour: 1,47 €; Hipercor: 1,69 €; El Corte ...
# 1545  Hipercor: 6,60 €; El Corte Inglés: 6,60 €; Mer...
# 1546                                     Eroski: 2,59 €
# 1547                                    Caprabo: 1,30 €
#
#                                             Description  \
# 0                                                   NaN
# 1     Descripción del producto - Cerveza estilo Pils...
# 2                                                   NaN
# 3                                                   NaN
# 4     Descripción del producto - Es una cerveza seca...
# ...                                                 ...
# 1543                                                NaN
# 1544                                                NaN
# 1545                                                NaN
# 1546                                                NaN
# 1547                                                NaN
#
#                                                   Image
# 0     https://a2.soysuper.com/175f8aab7364c96c12f88f...
# 1     https://a2.soysuper.com/bf10649181c8cfa2b925a5...
# 2     https://a1.soysuper.com/ad3d00baffa73167534a7f...
# 3     https://a1.soysuper.com/2614b35dc24707c6693ef9...
# 4     https://a1.soysuper.com/e4fce10af7cf9a2fbc09af...
# ...                                                 ...
# 1543  https://a1.soysuper.com/6a4baa29d3fd73c282b3c0...
# 1544  https://a1.soysuper.com/8cd780cd7991e332d967c3...
# 1545  https://a1.soysuper.com/5d11981c2ed05049b9d09f...
# 1546  https://a2.soysuper.com/899c34934e9f205fee702e...
# 1547  https://a1.soysuper.com/2c92c920ef588f55f87c08...
#
# [1548 rows x 7 columns]

# %%
# remove columns that are not needed
df = df.drop(['Product Link', 'Image'], axis=1)
df
# Out:
#                                                    Name Main Price  \
# 0            Rosa Blanca Cervezas\nRosa blanca Cervezas     4,29 €
# 1                         Cruzcampo\nCruzcampo Cervezas     8,04 €
# 2                       Estrella Galicia\nCervezas mini    11,49 €
# 3                   Estrella Galicia\nCervezas Especial    10,63 €
# 4                           Heineken\nHeineken Cervezas     9,61 €
# ...                                                 ...        ...
# 1543            La Casera\nAperitivo de sidra La Casera     1,47 €
# 1544                                Polar\nMaltín Polar     1,62 €
# 1545                            MALTIN\nBebida de malta     6,71 €
# 1546                         Kopparberg\nSidra tropical     2,59 €
# 1547  LADRÓN MANZANAS\nCider de manzana verde ladrón...     1,30 €
#
#                         lot Size  \
# 0            Pack 6 uds. x 25 cl
# 1            Pack 12 uds x 33 cl
# 2                Pack 20 x 20 cl
# 3           Pack 20 uds. x 20 cl
# 4      Pack de 12 latas de 33 cl
# ...                          ...
# 1543                  Lata 33 cl
# 1544                  Lata 33 cl
# 1545      Pack 6 botellas 250 ml
# 1546                  Lata 50 cl
# 1547              Botellín 25 cl
#
#                                 Supermarkets and Prices  \
# 0                                       Alcampo: 4,29 €
# 1     Mercadona: 5,88 €; Alcampo: 7,42 €; Hipercor: ...
# 2                                       Eroski: 11,49 €
# 3                   Alcampo: 9,86 €; Carrefour: 11,40 €
# 4     Mercadona: 8,33 €; Condis: 8,39 €; Alcampo: 8,...
# ...                                                 ...
# 1543                                  Carrefour: 1,47 €
# 1544  Carrefour: 1,47 €; Hipercor: 1,69 €; El Corte ...
# 1545  Hipercor: 6,60 €; El Corte Inglés: 6,60 €; Mer...
# 1546                                     Eroski: 2,59 €
# 1547                                    Caprabo: 1,30 €
#
#                                             Description
# 0                                                   NaN
# 1     Descripción del producto - Cerveza estilo Pils...
# 2                                                   NaN
# 3                                                   NaN
# 4     Descripción del producto - Es una cerveza seca...
# ...                                                 ...
# 1543                                                NaN
# 1544                                                NaN
# 1545                                                NaN
# 1546                                                NaN
# 1547                                                NaN
#
# [1548 rows x 5 columns]

# %%
# modify the 'Main Price' column to remove the Euro sign and strip whitespace and convert to numeric
df['Main Price'] = df['Main Price'].str.replace('€', '').str.replace(',','.').str.strip()
df['Main Price'] = pd.to_numeric(df['Main Price'], errors='coerce')
df
# Out:
#                                                    Name  Main Price  \
# 0            Rosa Blanca Cervezas\nRosa blanca Cervezas        4.29
# 1                         Cruzcampo\nCruzcampo Cervezas        8.04
# 2                       Estrella Galicia\nCervezas mini       11.49
# 3                   Estrella Galicia\nCervezas Especial       10.63
# 4                           Heineken\nHeineken Cervezas        9.61
# ...                                                 ...         ...
# 1543            La Casera\nAperitivo de sidra La Casera        1.47
# 1544                                Polar\nMaltín Polar        1.62
# 1545                            MALTIN\nBebida de malta        6.71
# 1546                         Kopparberg\nSidra tropical        2.59
# 1547  LADRÓN MANZANAS\nCider de manzana verde ladrón...        1.30
#
#                         lot Size  \
# 0            Pack 6 uds. x 25 cl
# 1            Pack 12 uds x 33 cl
# 2                Pack 20 x 20 cl
# 3           Pack 20 uds. x 20 cl
# 4      Pack de 12 latas de 33 cl
# ...                          ...
# 1543                  Lata 33 cl
# 1544                  Lata 33 cl
# 1545      Pack 6 botellas 250 ml
# 1546                  Lata 50 cl
# 1547              Botellín 25 cl
#
#                                 Supermarkets and Prices  \
# 0                                       Alcampo: 4,29 €
# 1     Mercadona: 5,88 €; Alcampo: 7,42 €; Hipercor: ...
# 2                                       Eroski: 11,49 €
# 3                   Alcampo: 9,86 €; Carrefour: 11,40 €
# 4     Mercadona: 8,33 €; Condis: 8,39 €; Alcampo: 8,...
# ...                                                 ...
# 1543                                  Carrefour: 1,47 €
# 1544  Carrefour: 1,47 €; Hipercor: 1,69 €; El Corte ...
# 1545  Hipercor: 6,60 €; El Corte Inglés: 6,60 €; Mer...
# 1546                                     Eroski: 2,59 €
# 1547                                    Caprabo: 1,30 €
#
#                                             Description
# 0                                                   NaN
# 1     Descripción del producto - Cerveza estilo Pils...
# 2                                                   NaN
# 3                                                   NaN
# 4     Descripción del producto - Es una cerveza seca...
# ...                                                 ...
# 1543                                                NaN
# 1544                                                NaN
# 1545                                                NaN
# 1546                                                NaN
# 1547                                                NaN
#
# [1548 rows x 5 columns]

# %%
# remove rows with 'sidra', 'vino', 'cider', 'colágeno' and 'vermut' in the 'Name' column
clean = (
    (df['Name'].str.contains('sidra', case=False, na=False) == False) &
    (df['Name'].str.contains('vino', case=False, na=False) == False) &
    (df['Name'].str.contains('cider', case=False, na=False) == False) &
    (df['Name'].str.contains('colágeno', case=False, na=False) == False) &
    (df['Name'].str.contains('vermut', case=False, na=False) == False)
)
df = df.loc[clean].reset_index(drop=True)
df
# Out:
#                                                  Name  Main Price  \
# 0          Rosa Blanca Cervezas\nRosa blanca Cervezas        4.29
# 1                       Cruzcampo\nCruzcampo Cervezas        8.04
# 2                     Estrella Galicia\nCervezas mini       11.49
# 3                 Estrella Galicia\nCervezas Especial       10.63
# 4                         Heineken\nHeineken Cervezas        9.61
# ...                                               ...         ...
# 1498                      Pony Malta\nBebida de malta        1.28
# 1499  Corona\nCorona Cerbeza 0,0% mejicana bot 33 cl.        1.33
# 1500                               BrewDog\nHazy Jane        2.61
# 1501                              Polar\nMaltín Polar        1.62
# 1502                          MALTIN\nBebida de malta        6.71
#
#                         lot Size  \
# 0            Pack 6 uds. x 25 cl
# 1            Pack 12 uds x 33 cl
# 2                Pack 20 x 20 cl
# 3           Pack 20 uds. x 20 cl
# 4      Pack de 12 latas de 33 cl
# ...                          ...
# 1498                  Lata 33 cl
# 1499                       33 cl
# 1500              Botellín 33 cl
# 1501                  Lata 33 cl
# 1502      Pack 6 botellas 250 ml
#
#                                 Supermarkets and Prices  \
# 0                                       Alcampo: 4,29 €
# 1     Mercadona: 5,88 €; Alcampo: 7,42 €; Hipercor: ...
# 2                                       Eroski: 11,49 €
# 3                   Alcampo: 9,86 €; Carrefour: 11,40 €
# 4     Mercadona: 8,33 €; Condis: 8,39 €; Alcampo: 8,...
# ...                                                 ...
# 1498                                     Eroski: 1,28 €
# 1499                                    Alcampo: 1,33 €
# 1500                                     Eroski: 2,61 €
# 1501  Carrefour: 1,47 €; Hipercor: 1,69 €; El Corte ...
# 1502  Hipercor: 6,60 €; El Corte Inglés: 6,60 €; Mer...
#
#                                             Description
# 0                                                   NaN
# 1     Descripción del producto - Cerveza estilo Pils...
# 2                                                   NaN
# 3                                                   NaN
# 4     Descripción del producto - Es una cerveza seca...
# ...                                                 ...
# 1498                                                NaN
# 1499                                                NaN
# 1500                                                NaN
# 1501                                                NaN
# 1502                                                NaN
#
# [1503 rows x 5 columns]

# %%
# replace the 'Supermarkets and Prices' column to remove the Euro sign and strip whitespace
df['Supermarkets and Prices'] = df['Supermarkets and Prices'].str.replace('€', '').str.replace(',','.').str.strip()
df
# Out:
#                                                  Name  Main Price  \
# 0          Rosa Blanca Cervezas\nRosa blanca Cervezas        4.29
# 1                       Cruzcampo\nCruzcampo Cervezas        8.04
# 2                     Estrella Galicia\nCervezas mini       11.49
# 3                 Estrella Galicia\nCervezas Especial       10.63
# 4                         Heineken\nHeineken Cervezas        9.61
# ...                                               ...         ...
# 1498                      Pony Malta\nBebida de malta        1.28
# 1499  Corona\nCorona Cerbeza 0,0% mejicana bot 33 cl.        1.33
# 1500                               BrewDog\nHazy Jane        2.61
# 1501                              Polar\nMaltín Polar        1.62
# 1502                          MALTIN\nBebida de malta        6.71
#
#                         lot Size  \
# 0            Pack 6 uds. x 25 cl
# 1            Pack 12 uds x 33 cl
# 2                Pack 20 x 20 cl
# 3           Pack 20 uds. x 20 cl
# 4      Pack de 12 latas de 33 cl
# ...                          ...
# 1498                  Lata 33 cl
# 1499                       33 cl
# 1500              Botellín 33 cl
# 1501                  Lata 33 cl
# 1502      Pack 6 botellas 250 ml
#
#                                 Supermarkets and Prices  \
# 0                                         Alcampo: 4.29
# 1     Mercadona: 5.88 ; Alcampo: 7.42 ; Hipercor: 8....
# 2                                         Eroski: 11.49
# 3                      Alcampo: 9.86 ; Carrefour: 11.40
# 4     Mercadona: 8.33 ; Condis: 8.39 ; Alcampo: 8.94...
# ...                                                 ...
# 1498                                       Eroski: 1.28
# 1499                                      Alcampo: 1.33
# 1500                                       Eroski: 2.61
# 1501  Carrefour: 1.47 ; Hipercor: 1.69 ; El Corte In...
# 1502  Hipercor: 6.60 ; El Corte Inglés: 6.60 ; Merca...
#
#                                             Description
# 0                                                   NaN
# 1     Descripción del producto - Cerveza estilo Pils...
# 2                                                   NaN
# 3                                                   NaN
# 4     Descripción del producto - Es una cerveza seca...
# ...                                                 ...
# 1498                                                NaN
# 1499                                                NaN
# 1500                                                NaN
# 1501                                                NaN
# 1502                                                NaN
#
# [1503 rows x 5 columns]

# %%
# replace '\n' with '-' in the 'Name' column
df['Name'] = df['Name'].str.replace('\n', '-')
df
# Out:
#                                                 Name  Main Price  \
# 0          Rosa Blanca Cervezas-Rosa blanca Cervezas        4.29
# 1                       Cruzcampo-Cruzcampo Cervezas        8.04
# 2                     Estrella Galicia-Cervezas mini       11.49
# 3                 Estrella Galicia-Cervezas Especial       10.63
# 4                         Heineken-Heineken Cervezas        9.61
# ...                                              ...         ...
# 1498                      Pony Malta-Bebida de malta        1.28
# 1499  Corona-Corona Cerbeza 0,0% mejicana bot 33 cl.        1.33
# 1500                               BrewDog-Hazy Jane        2.61
# 1501                              Polar-Maltín Polar        1.62
# 1502                          MALTIN-Bebida de malta        6.71
#
#                         lot Size  \
# 0            Pack 6 uds. x 25 cl
# 1            Pack 12 uds x 33 cl
# 2                Pack 20 x 20 cl
# 3           Pack 20 uds. x 20 cl
# 4      Pack de 12 latas de 33 cl
# ...                          ...
# 1498                  Lata 33 cl
# 1499                       33 cl
# 1500              Botellín 33 cl
# 1501                  Lata 33 cl
# 1502      Pack 6 botellas 250 ml
#
#                                 Supermarkets and Prices  \
# 0                                         Alcampo: 4.29
# 1     Mercadona: 5.88 ; Alcampo: 7.42 ; Hipercor: 8....
# 2                                         Eroski: 11.49
# 3                      Alcampo: 9.86 ; Carrefour: 11.40
# 4     Mercadona: 8.33 ; Condis: 8.39 ; Alcampo: 8.94...
# ...                                                 ...
# 1498                                       Eroski: 1.28
# 1499                                      Alcampo: 1.33
# 1500                                       Eroski: 2.61
# 1501  Carrefour: 1.47 ; Hipercor: 1.69 ; El Corte In...
# 1502  Hipercor: 6.60 ; El Corte Inglés: 6.60 ; Merca...
#
#                                             Description
# 0                                                   NaN
# 1     Descripción del producto - Cerveza estilo Pils...
# 2                                                   NaN
# 3                                                   NaN
# 4     Descripción del producto - Es una cerveza seca...
# ...                                                 ...
# 1498                                                NaN
# 1499                                                NaN
# 1500                                                NaN
# 1501                                                NaN
# 1502                                                NaN
#
# [1503 rows x 5 columns]

# %%
# count the number of beers that have 'botella' or 'botellín' in the 'lot Size' column
count_1 = df['lot Size'].str.contains('botella', case=False, na=False).sum() + \
          df['lot Size'].str.contains('botellín', case=False, na=False).sum()
print (f"Number of beers in 'Botella' or 'Botellín': {count_1}")

# count the number of beers that have 'lata' in the 'lot Size' column
count_2 = df['lot Size'].str.contains('lata', case=False, na=False).sum()
print (f"Number of beers in 'Lata': {count_2}")

# print the hypothesis based on the counts
if count_1 > count_2:
    print("Correct hypothesis: in Spanish supermarkets, the most common format for selling beer is 'Botella' or 'Botellín'.")
elif count_2 > count_1:
    print("Incorrect hypothesis: in Spanish supermarkets, the most common format for selling beer is 'Lata'.")
else:
    print("Both formats have the same frequency.")
# Out:
# Number of beers in 'Botella' or 'Botellín': 661
# Number of beers in 'Lata': 453
# Correct hypothesis: in Spanish supermarkets, the most common format for selling beer is 'Botella' or 'Botellín'.

# %%
# Export the cleaned DataFrame to Excel
df.to_excel('beers_spain_modify.xlsx', index=False)

# %%
#  Plotting the results. Testing the hypothesis
sns.barplot(x=['Botella/Botellín', 'Lata'], y=[count_1, count_2], palette=['#145A32', '#FFD700'])
plt.ylabel('Cantidad')
plt.title('Formato más común para la venta de cervezas') 
plt.show()
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_12920\1679314551.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=['Botella/Botellín', 'Lata'], y=[count_1, count_2], palette=['#145A32', '#FFD700'])

# %%
#Barplot of the 10 most frequent lot size formats
top10 = df['lot Size'].value_counts().nlargest(10)

plt.figure()
sns.barplot(
    x=top10.values,
    y=top10.index,
    palette='mako'
)
plt.title('Los 10 formatos de tamaño de lote más comunes')
plt.xlabel('Frecuencia')
plt.ylabel('Formato de tamaño de lote')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_12920\782714241.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
#Pie chart of the top 5 most common lot size formats
top5 = df['lot Size'].value_counts().nlargest(5)
plt.figure(figsize=(6,6))
plt.pie(
    top5.values,
    labels=top5.index,
    autopct='%1.1f%%',
)
plt.title('Los 5 formatos de tamaño de lote (porcentaje)')
plt.tight_layout()
plt.show()

# %%
# Main Price comparing latas vs. botellas
plt.figure(figsize=(8,5))
sns.kdeplot(
    data=df[df['lot Size'].str.contains('lata', case=False, na=False)],
    x='Main Price',
    label='Lata',
    fill=True,
    alpha=0.4
)
sns.kdeplot(
    data=df[df['lot Size'].str.contains('botell', case=False, na=False)],
    x='Main Price',
    label='Botella/Botellín',
    fill=True,
    alpha=0.4
)
plt.title('Distribución de precios: Latas vs. Botellas/Botellines')
plt.xlabel('Precios (€)')
plt.ylabel('Densidad')
plt.legend()
plt.tight_layout()
plt.show()
